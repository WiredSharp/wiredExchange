# %%
import pandas as pd
import numpy as np
import xlsxwriter as xl

# %%
tr = pd.read_csv('ftx_transactions.csv')

# %%
tr
# Out:
#    Unnamed: 0            id        market  future baseCurrency quoteCurrency  \
# 0           0  5.025969e+09      BTC/USDT     NaN          BTC          USDT
# 1           1  4.952958e+09      FTT/USDT     NaN          FTT          USDT
# 2           2  4.930918e+09      BTC/USDT     NaN          BTC          USDT
# 3           3  4.930744e+09      UNI/USDT     NaN          UNI          USDT
# 4           4  4.926392e+09      BTC/USDT     NaN          BTC          USDT
# 5           5  4.905309e+09           NaN     NaN      VETBULL          USDT
# 6           6  4.898901e+09  VETBULL/USDT     NaN      VETBULL          USDT
# 7           7  4.898537e+09      USDT/USD     NaN         USDT           USD
# 8           8  4.881956e+09     LINK/USDT     NaN         LINK          USDT
# 9           9  4.881918e+09     LINK/USDT     NaN         LINK          USDT
# 10         10  4.881042e+09      LTC/USDT     NaN          LTC          USDT
# ...

# %%
tr = pd.read_json('ftx_transactions.json')
tr.set_index('time', inplace=True)
tr.index = pd.to_datetime(tr.index)
tr = tr.astype({'market':'string','baseCurrency':'string', 'quoteCurrency': 'string', 'type': 'string', 'side': 'string', 'feeCurrency':'string', 'liquidity':'string'})
tr
# Out:
#                                           id        market  future  \
# time
# 2021-11-18 15:25:37.926962+00:00  5025968617      BTC/USDT     NaN
# 2021-11-16 00:02:30.522002+00:00  4952958183      FTT/USDT     NaN
# 2021-11-14 16:08:59.282310+00:00  4930917524      BTC/USDT     NaN
# 2021-11-14 15:57:45.893164+00:00  4930743785      UNI/USDT     NaN
# 2021-11-14 08:18:00.307858+00:00  4926391702      BTC/USDT     NaN
# 2021-11-12 22:13:44.751158+00:00  4905308716          <NA>     NaN
# 2021-11-12 15:23:12.086552+00:00  4898900962  VETBULL/USDT     NaN
# 2021-11-12 15:07:50.984461+00:00  4898536755      USDT/USD     NaN
# 2021-11-11 23:37:34.169602+00:00  4881956286     LINK/USDT     NaN
# 2021-11-11 23:34:56.468410+00:00  4881918058     LINK/USDT     NaN
# 2021-11-11 22:07:38.191006+00:00  4881041894      LTC/USDT     NaN
# 2021-11-11 22:04:48.556827+00:00  4881001038      SOL/USDT     NaN
# 2021-11-11 21:59:41.410165+00:00  4880932858  VETBULL/USDT     NaN
# ...

# %%
tr.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15 entries, 2021-11-18 15:25:37.926962+00:00 to 2021-11-11 20:54:36.896681+00:00
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             15 non-null     int64
#  1   market         14 non-null     string
#  2   future         0 non-null      float64
#  3   baseCurrency   15 non-null     string
#  4   quoteCurrency  15 non-null     string
#  5   type           15 non-null     string
#  6   side           15 non-null     string
#  7   price          15 non-null     float64
#  8   size           15 non-null     float64
#  9   orderId        14 non-null     float64
#  10  tradeId        14 non-null     float64
#  11  feeRate        15 non-null     float64
#  12  fee            15 non-null     float64
#  13  feeCurrency    15 non-null     string
#  14  liquidity      15 non-null     string
# dtypes: float64(7), int64(1), string(7)
# ...
